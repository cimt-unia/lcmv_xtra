# %%
# EXAMPLE USAGE 

from lcmv_xtra.viz import visualize_source_at_coordinate

visualize_source_at_coordinate(
    stc_path="/math/sub-001/source_estimate_LCMV.h5",
    mni_coord=[-42, -18, 56],
    roi_name="Left M1",
    base_dir="/path/derivatives/_fs",                   # fs_averaged directory
    psd_method='welch',                                 # 'welch' or 'multitaper'
    band_cmap="Purples_r"    
)
# Out:
# Requested: [-42, -18, 56]
# Closest active source: [-40.0, -20.0, 55.0] (dist: 3.0 mm)
