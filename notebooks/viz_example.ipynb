# %% [markdown]
# ## **Visualizers**

# %%
# Coordinates on fsaverage
from lcmv_xtra import plot_mni_orthoview

# Single coordinate
plot_mni_orthoview([-27, -18, 57], region_names=["Left M1"])

# %%
# CIMT Atlas
from lcmv_xtra import plot_cimt_rois


# Multiple ROIs
plot_cimt_rois([7, 187,8], label_type="full", title = "CIMT Atlas")

# %%
# PSD Comparison
from lcmv_xtra import plot_group_psd_comparison

EEG_DIR = "/eeg_tensor"

plot_group_psd_comparison(
    f"{EEG_DIR}/study_gain.npz",
    f"{EEG_DIR}/study_loss.npz",
    roi_indices=[0, 1],
    roi_names=["R1", "R2"],
    label_one="Gain", label_two="Loss",
    title_prefix="EEG"
)
# Out:
# [<Figure size 1000x400 with 1 Axes>, <Figure size 1000x400 with 1 Axes>]
