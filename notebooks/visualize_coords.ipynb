# %%
from lcmv_xtra import visualize_source_at_coordinate
visualize_source_at_coordinate(
    stc_path="/mnt/movement/users/jaizor/xtra/derivatives/lcmv/sub-001_bima_off/source_estimate_LCMV.h5",
    mni_coord=[-42, -18, 56],
    roi_name="Left M1",
    base_dir="/mnt/movement/users/jaizor/xtra/derivatives/_fs",
    psd_method='welch',  # or 'multitaper'
    band_cmap = 'Accent_r'

)
# Out:
# Requested: [-42, -18, 56]
# Closest active source: [-40.0, -20.0, 55.0] (dist: 3.0 mm)
# Band Powers (integrated):
#   Delta: 5.72e-03
#   Theta: 3.14e-03
#   Alpha: 1.31e-03
#   Low Beta: 1.92e-03
#   High Beta: 1.79e-03
#   Low Gamma: 2.66e-03
#   High Gamma: 4.39e-03
